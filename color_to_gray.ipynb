# %% [markdown]
# <a href="https://colab.research.google.com/github/akshita79/color-to_gray-image-Opencv/blob/main/color_to_gray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

# Path to the directory containing the images
images_dir = '/content/squares'

# Iterate through the image indices
for i in range(1, 101):
    # Construct the image filename
    filename = f'drawing{i}.png'  # Modify this line based on your image naming scheme

    # Read the image
    image_path = f'{images_dir}/{filename}'
    image = cv2.imread(image_path)

    # Check if the image exists
    if image is not None:
        # Convert the image to grayscale
        grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Save the grayscale image
        output_path = f'{outputfile}/grayscale_{filename}'
        cv2.imwrite(output_path, grayscale_image)
print("done")
# Out:
# done

# %%
import cv2
from google.colab.patches import cv2_imshow
#importing this is important as cv2.show doesn't work on colab as it crashes the session
image=cv2.imread("/content/googlelogo.svg.png")
greyscale_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(greyscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1200x1224 at 0x7FBC719F3610>
